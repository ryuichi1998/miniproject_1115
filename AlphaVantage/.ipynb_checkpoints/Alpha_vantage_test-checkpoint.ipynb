# %%
apikey='GOJKUKZEAK5QIOUW'
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key=apikey,output_format='pandas')

# %%
data, meta_data = ts.get_daily(symbol='MSFT', outputsize='full')

# %%
plt.figure(figsize=(20,10))
data['4. close'].plot()
plt.title('Daily Times Series for the MSFT stock')
plt.show()

# %%
data, meta_data = ts.get_daily(symbol='GOOGL', outputsize='full')

# %%
plt.figure(figsize=(20,10))
data['4. close'].plot()
plt.title('Daily Times Series for the GOOGL stock')
plt.show()

# %%
data, meta_data = ts.get_daily(symbol='TSLA', outputsize='full')

# %%
plt.figure(figsize=(20,10))
data['4. close'].plot()
plt.title('Daily Times Series for the TSLA stock')
plt.show()

# %%
data, meta_data = ts.get_daily(symbol='AAPL', outputsize='full')

# %%
plt.figure(figsize=(20,10))
data['4. close'].plot()
plt.title('Daily Times Series for the AAPL stock')
plt.show()
